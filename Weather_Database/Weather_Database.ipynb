# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import random
from config import weather_api_key
import time
from datetime import datetime
from citipy import citipy

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs
# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
# If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 767

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | baykit
# Processing Record 2 of Set 1 | castro
# Processing Record 3 of Set 1 | puerto ayora
# Processing Record 4 of Set 1 | omaruru
# Processing Record 5 of Set 1 | bure
# Processing Record 6 of Set 1 | sinnai
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | torbay
# Processing Record 9 of Set 1 | la macarena
# Processing Record 10 of Set 1 | maksatikha
# Processing Record 11 of Set 1 | pevek
# Processing Record 12 of Set 1 | arraial do cabo
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | tiksi
# Processing Record 15 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | naze
# Processing Record 18 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 1 | saint-philippe
# Processing Record 20 of Set 1 | dikson
# Processing Record 21 of Set 1 | iqaluit
# Processing Record 22 of Set 1 | cape town
# Processing Record 23 of Set 1 | kathu
# Processing Record 24 of Set 1 | talnakh
# Processing Record 25 of Set 1 | new norfolk
# Processing Record 26 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 1 | bathsheba
# Processing Record 28 of Set 1 | sladkovo
# Processing Record 29 of Set 1 | katsuura
# Processing Record 30 of Set 1 | rikitea
# Processing Record 31 of Set 1 | tasiilaq
# Processing Record 32 of Set 1 | ushuaia
# Processing Record 33 of Set 1 | port elizabeth
# Processing Record 34 of Set 1 | khatima
# Processing Record 35 of Set 1 | plettenberg bay
# Processing Record 36 of Set 1 | butaritari
# Processing Record 37 of Set 1 | pietersburg
# Processing Record 38 of Set 1 | jamestown
# Processing Record 39 of Set 1 | seoul
# Processing Record 40 of Set 1 | kirakira
# Processing Record 41 of Set 1 | malanje
# Processing Record 42 of Set 1 | barrow
# Processing Record 43 of Set 1 | angamacutiro
# City not found. Skipping...
# Processing Record 44 of Set 1 | murgab
# Processing Record 45 of Set 1 | bredasdorp
# Processing Record 46 of Set 1 | nanortalik
# Processing Record 47 of Set 1 | marsh harbour
# Processing Record 48 of Set 1 | dingle
# Processing Record 49 of Set 1 | raudeberg
# Processing Record 50 of Set 1 | agadez
# Processing Record 1 of Set 2 | hobart
# Processing Record 2 of Set 2 | chiredzi
# Processing Record 3 of Set 2 | hermanus
# Processing Record 4 of Set 2 | paita
# Processing Record 5 of Set 2 | vila franca do campo
# Processing Record 6 of Set 2 | ancud
# Processing Record 7 of Set 2 | hilo
# Processing Record 8 of Set 2 | tweed
# Processing Record 9 of Set 2 | khatanga
# Processing Record 10 of Set 2 | kavieng
# Processing Record 11 of Set 2 | karratha
# Processing Record 12 of Set 2 | orlik
# Processing Record 13 of Set 2 | leningradskiy
# Processing Record 14 of Set 2 | mount isa
# Processing Record 15 of Set 2 | port hedland
# Processing Record 16 of Set 2 | bambous virieux
# Processing Record 17 of Set 2 | port alfred
# Processing Record 18 of Set 2 | khlung
# Processing Record 19 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 2 | portland
# Processing Record 21 of Set 2 | esperance
# Processing Record 22 of Set 2 | hamilton
# Processing Record 23 of Set 2 | busselton
# Processing Record 24 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 2 | bluff
# Processing Record 26 of Set 2 | provideniya
# Processing Record 27 of Set 2 | aleksandrovka
# Processing Record 28 of Set 2 | isangel
# Processing Record 29 of Set 2 | lompoc
# Processing Record 30 of Set 2 | bethel
# Processing Record 31 of Set 2 | longyearbyen
# Processing Record 32 of Set 2 | kodiak
# Processing Record 33 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 34 of Set 2 | poum
# Processing Record 35 of Set 2 | kawana waters
# City not found. Skipping...
# Processing Record 36 of Set 2 | kapaa
# Processing Record 37 of Set 2 | eyrarbakki
# Processing Record 38 of Set 2 | kaitangata
# Processing Record 39 of Set 2 | telhara
# Processing Record 40 of Set 2 | labuhan
# Processing Record 41 of Set 2 | awjilah
# Processing Record 42 of Set 2 | belaya gora
# Processing Record 43 of Set 2 | sento se
# City not found. Skipping...
# Processing Record 44 of Set 2 | cabo san lucas
# Processing Record 45 of Set 2 | stulovo
# Processing Record 46 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 2 | tulum
# Processing Record 48 of Set 2 | waingapu
# Processing Record 49 of Set 2 | najran
# Processing Record 50 of Set 2 | asau
# Processing Record 1 of Set 3 | ballina
# Processing Record 2 of Set 3 | kamenka
# Processing Record 3 of Set 3 | nador
# Processing Record 4 of Set 3 | alofi
# Processing Record 5 of Set 3 | college
# Processing Record 6 of Set 3 | korla
# Processing Record 7 of Set 3 | ribeira grande
# Processing Record 8 of Set 3 | grand gaube
# Processing Record 9 of Set 3 | atuona
# Processing Record 10 of Set 3 | avarua
# Processing Record 11 of Set 3 | pacific grove
# Processing Record 12 of Set 3 | pangani
# Processing Record 13 of Set 3 | norman wells
# Processing Record 14 of Set 3 | cidreira
# Processing Record 15 of Set 3 | guerrero negro
# Processing Record 16 of Set 3 | betare oya
# Processing Record 17 of Set 3 | trelew
# Processing Record 18 of Set 3 | general roca
# Processing Record 19 of Set 3 | banamba
# Processing Record 20 of Set 3 | baruun-urt
# Processing Record 21 of Set 3 | hithadhoo
# Processing Record 22 of Set 3 | sabha
# Processing Record 23 of Set 3 | viransehir
# Processing Record 24 of Set 3 | port hardy
# Processing Record 25 of Set 3 | rocha
# Processing Record 26 of Set 3 | east london
# Processing Record 27 of Set 3 | vao
# Processing Record 28 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 3 | thompson
# Processing Record 30 of Set 3 | miyoshi
# Processing Record 31 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 32 of Set 3 | cassilandia
# Processing Record 33 of Set 3 | scarborough
# Processing Record 34 of Set 3 | keti bandar
# Processing Record 35 of Set 3 | paragominas
# Processing Record 36 of Set 3 | bajo baudo
# City not found. Skipping...
# Processing Record 37 of Set 3 | yulara
# Processing Record 38 of Set 3 | hasaki
# Processing Record 39 of Set 3 | ilulissat
# Processing Record 40 of Set 3 | qaanaaq
# Processing Record 41 of Set 3 | nkowakowa
# Processing Record 42 of Set 3 | beloha
# Processing Record 43 of Set 3 | tocopilla
# Processing Record 44 of Set 3 | sept-iles
# Processing Record 45 of Set 3 | san cristobal
# Processing Record 46 of Set 3 | quatre cocos
# Processing Record 47 of Set 3 | xiongzhou
# Processing Record 48 of Set 3 | richards bay
# Processing Record 49 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 3 | vrangel
# Processing Record 1 of Set 4 | praia da vitoria
# Processing Record 2 of Set 4 | nikolskoye
# Processing Record 3 of Set 4 | waipawa
# Processing Record 4 of Set 4 | pangnirtung
# Processing Record 5 of Set 4 | maldonado
# Processing Record 6 of Set 4 | saldanha
# Processing Record 7 of Set 4 | diego de almagro
# Processing Record 8 of Set 4 | nikki
# Processing Record 9 of Set 4 | paamiut
# Processing Record 10 of Set 4 | cody
# Processing Record 11 of Set 4 | obo
# Processing Record 12 of Set 4 | yellowknife
# Processing Record 13 of Set 4 | porbandar
# Processing Record 14 of Set 4 | caravelas
# Processing Record 15 of Set 4 | namwala
# Processing Record 16 of Set 4 | lappeenranta
# Processing Record 17 of Set 4 | benjamin hill
# Processing Record 18 of Set 4 | vaini
# Processing Record 19 of Set 4 | kyshtovka
# Processing Record 20 of Set 4 | opelousas
# Processing Record 21 of Set 4 | muros
# Processing Record 22 of Set 4 | rio gallegos
# Processing Record 23 of Set 4 | los llanos de aridane
# Processing Record 24 of Set 4 | meulaboh
# Processing Record 25 of Set 4 | ajaccio
# Processing Record 26 of Set 4 | beringovskiy
# Processing Record 27 of Set 4 | orikhove
# Processing Record 28 of Set 4 | suntar
# Processing Record 29 of Set 4 | nhulunbuy
# Processing Record 30 of Set 4 | saskylakh
# Processing Record 31 of Set 4 | carmen
# Processing Record 32 of Set 4 | gibara
# Processing Record 33 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 4 | sile
# Processing Record 35 of Set 4 | verkhoyansk
# Processing Record 36 of Set 4 | tonj
# Processing Record 37 of Set 4 | mbuyapey
# Processing Record 38 of Set 4 | pelotas
# Processing Record 39 of Set 4 | bullas
# Processing Record 40 of Set 4 | chokurdakh
# Processing Record 41 of Set 4 | rawson
# Processing Record 42 of Set 4 | mizpe ramon
# City not found. Skipping...
# Processing Record 43 of Set 4 | marienburg
# Processing Record 44 of Set 4 | lichuan
# Processing Record 45 of Set 4 | joutseno
# Processing Record 46 of Set 4 | kyzyl-suu
# Processing Record 47 of Set 4 | pestretsy
# Processing Record 48 of Set 4 | saryshagan
# City not found. Skipping...
# Processing Record 49 of Set 4 | povenets
# Processing Record 50 of Set 4 | nha trang
# Processing Record 1 of Set 5 | narsaq
# Processing Record 2 of Set 5 | pitimbu
# Processing Record 3 of Set 5 | tautira
# Processing Record 4 of Set 5 | quibdo
# Processing Record 5 of Set 5 | republic
# Processing Record 6 of Set 5 | pemangkat
# Processing Record 7 of Set 5 | pathein
# Processing Record 8 of Set 5 | kruisfontein
# Processing Record 9 of Set 5 | guanica
# Processing Record 10 of Set 5 | buala
# Processing Record 11 of Set 5 | longlac
# City not found. Skipping...
# Processing Record 12 of Set 5 | victoria
# Processing Record 13 of Set 5 | upernavik
# Processing Record 14 of Set 5 | krasnoselkup
# Processing Record 15 of Set 5 | monkey bay
# Processing Record 16 of Set 5 | mahebourg
# Processing Record 17 of Set 5 | cascais
# Processing Record 18 of Set 5 | lampitak
# Processing Record 19 of Set 5 | nome
# Processing Record 20 of Set 5 | verkhnyaya toyma
# Processing Record 21 of Set 5 | kodinsk
# Processing Record 22 of Set 5 | challapata
# Processing Record 23 of Set 5 | carmo do paranaiba
# Processing Record 24 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 5 | solnechnyy
# Processing Record 26 of Set 5 | skalistyy
# City not found. Skipping...
# Processing Record 27 of Set 5 | nieuw nickerie
# Processing Record 28 of Set 5 | ryazanovskiy
# Processing Record 29 of Set 5 | umm lajj
# Processing Record 30 of Set 5 | souillac
# Processing Record 31 of Set 5 | omboue
# Processing Record 32 of Set 5 | chuy
# Processing Record 33 of Set 5 | liyang
# Processing Record 34 of Set 5 | mar del plata
# Processing Record 35 of Set 5 | skibotn
# Processing Record 36 of Set 5 | esso
# Processing Record 37 of Set 5 | tuktoyaktuk
# Processing Record 38 of Set 5 | tuatapere
# Processing Record 39 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 5 | ellenabad
# Processing Record 41 of Set 5 | bengkulu
# Processing Record 42 of Set 5 | havre-saint-pierre
# Processing Record 43 of Set 5 | tuggurt
# City not found. Skipping...
# Processing Record 44 of Set 5 | gizo
# Processing Record 45 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 5 | tupelo
# Processing Record 47 of Set 5 | sao miguel do araguaia
# Processing Record 48 of Set 5 | muli
# Processing Record 49 of Set 5 | constantine
# Processing Record 50 of Set 5 | dunedin
# Processing Record 1 of Set 6 | sioux lookout
# Processing Record 2 of Set 6 | baherden
# Processing Record 3 of Set 6 | bani
# Processing Record 4 of Set 6 | kichera
# Processing Record 5 of Set 6 | bandarbeyla
# Processing Record 6 of Set 6 | zhangjiakou
# Processing Record 7 of Set 6 | udachnyy
# Processing Record 8 of Set 6 | vagay
# Processing Record 9 of Set 6 | lebu
# Processing Record 10 of Set 6 | vila velha
# Processing Record 11 of Set 6 | margate
# Processing Record 12 of Set 6 | yar-sale
# Processing Record 13 of Set 6 | mogadishu
# Processing Record 14 of Set 6 | toftir
# City not found. Skipping...
# Processing Record 15 of Set 6 | kaputa
# Processing Record 16 of Set 6 | gulshat
# City not found. Skipping...
# Processing Record 17 of Set 6 | moses lake
# Processing Record 18 of Set 6 | vanimo
# Processing Record 19 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 20 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 21 of Set 6 | sorland
# Processing Record 22 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 6 | ngunguru
# Processing Record 24 of Set 6 | broken hill
# Processing Record 25 of Set 6 | limbang
# Processing Record 26 of Set 6 | nagram
# Processing Record 27 of Set 6 | ponta do sol
# Processing Record 28 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 29 of Set 6 | willowmore
# Processing Record 30 of Set 6 | bentiu
# Processing Record 31 of Set 6 | port keats
# Processing Record 32 of Set 6 | codrington
# Processing Record 33 of Set 6 | chapais
# Processing Record 34 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 6 | port macquarie
# Processing Record 36 of Set 6 | terrace
# Processing Record 37 of Set 6 | kalakamati
# Processing Record 38 of Set 6 | mount gambier
# Processing Record 39 of Set 6 | vestmanna
# Processing Record 40 of Set 6 | port lincoln
# Processing Record 41 of Set 6 | klaksvik
# Processing Record 42 of Set 6 | rundu
# Processing Record 43 of Set 6 | bukachacha
# Processing Record 44 of Set 6 | kousseri
# Processing Record 45 of Set 6 | luderitz
# Processing Record 46 of Set 6 | altay
# Processing Record 47 of Set 6 | fortuna
# Processing Record 48 of Set 6 | faanui
# Processing Record 49 of Set 6 | coihaique
# Processing Record 50 of Set 6 | hobyo
# Processing Record 1 of Set 7 | zhigansk
# Processing Record 2 of Set 7 | chuari khas
# Processing Record 3 of Set 7 | weligama
# Processing Record 4 of Set 7 | tamandare
# Processing Record 5 of Set 7 | komsomolets
# Processing Record 6 of Set 7 | mzimba
# Processing Record 7 of Set 7 | palamos
# Processing Record 8 of Set 7 | khandbari
# Processing Record 9 of Set 7 | fort myers beach
# Processing Record 10 of Set 7 | villena
# Processing Record 11 of Set 7 | zachagansk
# City not found. Skipping...
# Processing Record 12 of Set 7 | waitati
# Processing Record 13 of Set 7 | itanhaem
# Processing Record 14 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 15 of Set 7 | san andres
# Processing Record 16 of Set 7 | serenje
# Processing Record 17 of Set 7 | riyadh
# Processing Record 18 of Set 7 | azanka
# Processing Record 19 of Set 7 | gat
# Processing Record 20 of Set 7 | charallave
# Processing Record 21 of Set 7 | lorengau
# Processing Record 22 of Set 7 | shelburne
# Processing Record 23 of Set 7 | elat
# Processing Record 24 of Set 7 | corinto
# Processing Record 25 of Set 7 | kavaratti
# Processing Record 26 of Set 7 | vestmannaeyjar
# Processing Record 27 of Set 7 | san quintin
# Processing Record 28 of Set 7 | kushiro
# Processing Record 29 of Set 7 | theologos
# City not found. Skipping...
# Processing Record 30 of Set 7 | gilbues
# Processing Record 31 of Set 7 | rio grande
# Processing Record 32 of Set 7 | san patricio
# Processing Record 33 of Set 7 | maceio
# Processing Record 34 of Set 7 | porto recanati
# Processing Record 35 of Set 7 | nizhniy kuranakh
# Processing Record 36 of Set 7 | gayny
# Processing Record 37 of Set 7 | la ronge
# Processing Record 38 of Set 7 | nelson
# Processing Record 39 of Set 7 | honningsvag
# Processing Record 40 of Set 7 | sinnamary
# Processing Record 41 of Set 7 | fairbanks
# Processing Record 42 of Set 7 | sars
# Processing Record 43 of Set 7 | lerwick
# Processing Record 44 of Set 7 | neiafu
# Processing Record 45 of Set 7 | erzin
# Processing Record 46 of Set 7 | lagoa
# Processing Record 47 of Set 7 | hambantota
# Processing Record 48 of Set 7 | ozgon
# City not found. Skipping...
# Processing Record 49 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 50 of Set 7 | damara
# Processing Record 1 of Set 8 | chingirlau
# Processing Record 2 of Set 8 | sisophon
# Processing Record 3 of Set 8 | amudat
# Processing Record 4 of Set 8 | noshiro
# Processing Record 5 of Set 8 | tymovskoye
# Processing Record 6 of Set 8 | samarinda
# Processing Record 7 of Set 8 | masvingo
# Processing Record 8 of Set 8 | ilhabela
# Processing Record 9 of Set 8 | nemuro
# Processing Record 10 of Set 8 | saint-augustin
# Processing Record 11 of Set 8 | mtwara
# Processing Record 12 of Set 8 | kuytun
# Processing Record 13 of Set 8 | manono
# Processing Record 14 of Set 8 | lensk
# Processing Record 15 of Set 8 | cockburn harbour
# City not found. Skipping...
# Processing Record 16 of Set 8 | itoman
# Processing Record 17 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 18 of Set 8 | husavik
# Processing Record 19 of Set 8 | aquiraz
# Processing Record 20 of Set 8 | brae
# Processing Record 21 of Set 8 | ban dung
# Processing Record 22 of Set 8 | sirsi
# Processing Record 23 of Set 8 | wencheng
# Processing Record 24 of Set 8 | cafarnaum
# Processing Record 25 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 26 of Set 8 | mackay
# Processing Record 27 of Set 8 | mabaruma
# Processing Record 28 of Set 8 | el tocuyo
# Processing Record 29 of Set 8 | neuenhagen
# Processing Record 30 of Set 8 | kemijarvi
# Processing Record 31 of Set 8 | andrews
# Processing Record 32 of Set 8 | frolovo
# Processing Record 33 of Set 8 | mehran
# Processing Record 34 of Set 8 | sao joao da barra
# Processing Record 35 of Set 8 | el dorado
# Processing Record 36 of Set 8 | lisakovsk
# Processing Record 37 of Set 8 | wolfsberg
# Processing Record 38 of Set 8 | chara
# Processing Record 39 of Set 8 | axim
# Processing Record 40 of Set 8 | roald
# Processing Record 41 of Set 8 | catacamas
# Processing Record 42 of Set 8 | geraldton
# Processing Record 43 of Set 8 | sambava
# Processing Record 44 of Set 8 | papara
# Processing Record 45 of Set 8 | tevaitoa
# Processing Record 46 of Set 8 | nouadhibou
# Processing Record 47 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 8 | okhotsk
# Processing Record 49 of Set 8 | georgetown
# Processing Record 50 of Set 8 | kahului
# Processing Record 1 of Set 9 | boa vista
# Processing Record 2 of Set 9 | katsiveli
# City not found. Skipping...
# Processing Record 3 of Set 9 | bud
# Processing Record 4 of Set 9 | half moon bay
# Processing Record 5 of Set 9 | lubao
# Processing Record 6 of Set 9 | bar harbor
# Processing Record 7 of Set 9 | sombrio
# Processing Record 8 of Set 9 | along
# Processing Record 9 of Set 9 | zeya
# Processing Record 10 of Set 9 | pozega
# Processing Record 11 of Set 9 | inuvik
# Processing Record 12 of Set 9 | lakes entrance
# Processing Record 13 of Set 9 | quelimane
# Processing Record 14 of Set 9 | novoagansk
# Processing Record 15 of Set 9 | ostuni
# Processing Record 16 of Set 9 | tongliao
# Processing Record 17 of Set 9 | kidal
# Processing Record 18 of Set 9 | litoral del san juan
# City not found. Skipping...
# Processing Record 19 of Set 9 | lengshuitan
# Processing Record 20 of Set 9 | gambela
# Processing Record 21 of Set 9 | marawi
# Processing Record 22 of Set 9 | masuguru
# Processing Record 23 of Set 9 | oriximina
# Processing Record 24 of Set 9 | grindavik
# Processing Record 25 of Set 9 | puerto escondido
# Processing Record 26 of Set 9 | ostrovnoy
# Processing Record 27 of Set 9 | son la
# Processing Record 28 of Set 9 | saint george
# Processing Record 29 of Set 9 | port hawkesbury
# Processing Record 30 of Set 9 | lincoln
# Processing Record 31 of Set 9 | gigmoto
# Processing Record 32 of Set 9 | verkh-usugli
# Processing Record 33 of Set 9 | unguia
# Processing Record 34 of Set 9 | toora-khem
# Processing Record 35 of Set 9 | guayaramerin
# Processing Record 36 of Set 9 | aljezur
# Processing Record 37 of Set 9 | pisco
# Processing Record 38 of Set 9 | urengoy
# Processing Record 39 of Set 9 | chalmette
# Processing Record 40 of Set 9 | kaeo
# Processing Record 41 of Set 9 | hirara
# Processing Record 42 of Set 9 | palmer
# Processing Record 43 of Set 9 | carballo
# Processing Record 44 of Set 9 | nantucket
# Processing Record 45 of Set 9 | peniche
# Processing Record 46 of Set 9 | apac
# Processing Record 47 of Set 9 | komsomolskiy
# Processing Record 48 of Set 9 | calama
# Processing Record 49 of Set 9 | el alto
# Processing Record 50 of Set 9 | ossora
# Processing Record 1 of Set 10 | mitsamiouli
# Processing Record 2 of Set 10 | sarakhs
# Processing Record 3 of Set 10 | garmsar
# Processing Record 4 of Set 10 | shemordan
# Processing Record 5 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 6 of Set 10 | airai
# Processing Record 7 of Set 10 | lindi
# Processing Record 8 of Set 10 | lavrentiya
# Processing Record 9 of Set 10 | enshi
# Processing Record 10 of Set 10 | yarkovo
# Processing Record 11 of Set 10 | ruse
# Processing Record 12 of Set 10 | sao lourenco do sul
# Processing Record 13 of Set 10 | byron bay
# Processing Record 14 of Set 10 | fulton
# Processing Record 15 of Set 10 | yuanli
# Processing Record 16 of Set 10 | borlange
# City not found. Skipping...
# Processing Record 17 of Set 10 | constitucion
# Processing Record 18 of Set 10 | sosva
# Processing Record 19 of Set 10 | bireun
# Processing Record 20 of Set 10 | carnarvon
# Processing Record 21 of Set 10 | laje
# Processing Record 22 of Set 10 | grinnell
# Processing Record 23 of Set 10 | governador valadares
# Processing Record 24 of Set 10 | san rafael
# Processing Record 25 of Set 10 | baglan
# Processing Record 26 of Set 10 | flinders
# Processing Record 27 of Set 10 | lulea
# Processing Record 28 of Set 10 | menongue
# Processing Record 29 of Set 10 | boffa
# Processing Record 30 of Set 10 | skagen
# Processing Record 31 of Set 10 | ouesso
# Processing Record 32 of Set 10 | shingu
# Processing Record 33 of Set 10 | mecca
# Processing Record 34 of Set 10 | muramvya
# Processing Record 35 of Set 10 | placido de castro
# Processing Record 36 of Set 10 | gornyy
# Processing Record 37 of Set 10 | presidencia roque saenz pena
# Processing Record 38 of Set 10 | sobolevo
# Processing Record 39 of Set 10 | siwani
# City not found. Skipping...
# Processing Record 40 of Set 10 | kandi
# Processing Record 41 of Set 10 | lieksa
# Processing Record 42 of Set 10 | salta
# Processing Record 43 of Set 10 | saint-georges
# Processing Record 44 of Set 10 | tarnobrzeg
# Processing Record 45 of Set 10 | kushmurun
# Processing Record 46 of Set 10 | itaguai
# Processing Record 47 of Set 10 | port-gentil
# Processing Record 48 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 49 of Set 10 | koulamoutou
# Processing Record 50 of Set 10 | ribeira do pombal
# Processing Record 1 of Set 11 | bayonet point
# Processing Record 2 of Set 11 | cockburn town
# Processing Record 3 of Set 11 | barranca
# Processing Record 4 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 11 | mareeba
# Processing Record 6 of Set 11 | severo-kurilsk
# Processing Record 7 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 8 of Set 11 | san miguel
# Processing Record 9 of Set 11 | astoria
# Processing Record 10 of Set 11 | dongsheng
# Processing Record 11 of Set 11 | necochea
# Processing Record 12 of Set 11 | athabasca
# Processing Record 13 of Set 11 | kapit
# Processing Record 14 of Set 11 | homestead
# Processing Record 15 of Set 11 | kirgiz-miyaki
# Processing Record 16 of Set 11 | zhemchuzhnyy
# City not found. Skipping...
# Processing Record 17 of Set 11 | mazara del vallo
# Processing Record 18 of Set 11 | georgiyevka
# Processing Record 19 of Set 11 | moron
# Processing Record 20 of Set 11 | mapiripan
# Processing Record 21 of Set 11 | remontnoye
# Processing Record 22 of Set 11 | vila
# Processing Record 23 of Set 11 | kiunga
# Processing Record 24 of Set 11 | deer lake
# Processing Record 25 of Set 11 | guarare
# Processing Record 26 of Set 11 | sandwick
# Processing Record 27 of Set 11 | itarema
# Processing Record 28 of Set 11 | kemin
# Processing Record 29 of Set 11 | tomatlan
# Processing Record 30 of Set 11 | santa isabel do rio negro
# Processing Record 31 of Set 11 | ahualulco
# Processing Record 32 of Set 11 | manggar
# Processing Record 33 of Set 11 | ginda
# Processing Record 34 of Set 11 | zhanatas
# City not found. Skipping...
# Processing Record 35 of Set 11 | labuan
# Processing Record 36 of Set 11 | vardo
# Processing Record 37 of Set 11 | yelnya
# Processing Record 38 of Set 11 | rexburg
# Processing Record 39 of Set 11 | luganville
# Processing Record 40 of Set 11 | puntarenas
# Processing Record 41 of Set 11 | puerto penasco
# Processing Record 42 of Set 11 | fuerte olimpo
# Processing Record 43 of Set 11 | herat
# Processing Record 44 of Set 11 | tual
# Processing Record 45 of Set 11 | porto walter
# Processing Record 46 of Set 11 | deputatskiy
# Processing Record 47 of Set 11 | hondo
# Processing Record 48 of Set 11 | mutsamudu
# City not found. Skipping...
# Processing Record 49 of Set 11 | hay river
# Processing Record 50 of Set 11 | marquette
# Processing Record 1 of Set 12 | bambanglipuro
# Processing Record 2 of Set 12 | skegness
# Processing Record 3 of Set 12 | liverpool
# Processing Record 4 of Set 12 | port blair
# Processing Record 5 of Set 12 | touros
# Processing Record 6 of Set 12 | barcelona
# Processing Record 7 of Set 12 | nabire
# Processing Record 8 of Set 12 | sol-iletsk
# Processing Record 9 of Set 12 | sur
# Processing Record 10 of Set 12 | kropotkin
# Processing Record 11 of Set 12 | thinadhoo
# Processing Record 12 of Set 12 | colac
# Processing Record 13 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 14 of Set 12 | tecoanapa
# Processing Record 15 of Set 12 | kailua
# Processing Record 16 of Set 12 | kazanskoye
# Processing Record 17 of Set 12 | kudahuvadhoo
# Processing Record 18 of Set 12 | bonthe
# Processing Record 19 of Set 12 | mbandaka
# Processing Record 20 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 21 of Set 12 | faridkot
# Processing Record 22 of Set 12 | kirovsk
# Processing Record 23 of Set 12 | wenchi
# Processing Record 24 of Set 12 | stupava
# Processing Record 25 of Set 12 | tura
# Processing Record 26 of Set 12 | naryan-mar
# Processing Record 27 of Set 12 | digri
# Processing Record 28 of Set 12 | vizinga
# Processing Record 29 of Set 12 | belmonte
# Processing Record 30 of Set 12 | qiryat gat
# Processing Record 31 of Set 12 | soyo
# Processing Record 32 of Set 12 | kazerun
# Processing Record 33 of Set 12 | storforshei
# Processing Record 34 of Set 12 | kashary
# Processing Record 35 of Set 12 | tak
# Processing Record 36 of Set 12 | kokologo
# Processing Record 37 of Set 12 | namibe
# Processing Record 38 of Set 12 | beni
# Processing Record 39 of Set 12 | wahpeton
# Processing Record 40 of Set 12 | almaznyy
# Processing Record 41 of Set 12 | sisimiut
# Processing Record 42 of Set 12 | jalu
# Processing Record 43 of Set 12 | maniitsoq
# Processing Record 44 of Set 12 | safaqis
# City not found. Skipping...
# Processing Record 45 of Set 12 | muzaffarpur
# Processing Record 46 of Set 12 | kargil
# Processing Record 47 of Set 12 | arrecife
# Processing Record 48 of Set 12 | zholymbet
# Processing Record 49 of Set 12 | lodja
# Processing Record 50 of Set 12 | lishan
# Processing Record 1 of Set 13 | deniliquin
# Processing Record 2 of Set 13 | le tampon
# Processing Record 3 of Set 13 | sao filipe
# Processing Record 4 of Set 13 | banda aceh
# Processing Record 5 of Set 13 | belyy yar
# Processing Record 6 of Set 13 | tabas
# Processing Record 7 of Set 13 | mkushi
# Processing Record 8 of Set 13 | tucurui
# Processing Record 9 of Set 13 | mandali
# Processing Record 10 of Set 13 | sitka
# Processing Record 11 of Set 13 | avera
# Processing Record 12 of Set 13 | hami
# Processing Record 13 of Set 13 | kenai
# Processing Record 14 of Set 13 | aykhal
# Processing Record 15 of Set 13 | tawkar
# City not found. Skipping...
# Processing Record 16 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 17 of Set 13 | barra do garcas
# Processing Record 18 of Set 13 | port moresby
# Processing Record 19 of Set 13 | contamana
# Processing Record 20 of Set 13 | saint-denis
# Processing Record 21 of Set 13 | rosetta
# Processing Record 22 of Set 13 | sitges
# Processing Record 23 of Set 13 | lardos
# Processing Record 24 of Set 13 | wa
# City not found. Skipping...
# Processing Record 25 of Set 13 | lata
# Processing Record 26 of Set 13 | muhos
# Processing Record 27 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 28 of Set 13 | tabou
# Processing Record 29 of Set 13 | huaicheng
# Processing Record 30 of Set 13 | gamba
# Processing Record 31 of Set 13 | nishihara
# Processing Record 32 of Set 13 | chumikan
# Processing Record 33 of Set 13 | hovd
# Processing Record 34 of Set 13 | akyab
# Processing Record 35 of Set 13 | innisfail
# Processing Record 36 of Set 13 | mahon
# Processing Record 37 of Set 13 | vostok
# Processing Record 38 of Set 13 | ambilobe
# Processing Record 39 of Set 13 | salme
# Processing Record 40 of Set 13 | smithers
# Processing Record 41 of Set 13 | kikwit
# Processing Record 42 of Set 13 | eureka
# Processing Record 43 of Set 13 | pangody
# Processing Record 44 of Set 13 | senanga
# Processing Record 45 of Set 13 | iguape
# Processing Record 46 of Set 13 | alyangula
# Processing Record 47 of Set 13 | klamath falls
# Processing Record 48 of Set 13 | talaya
# Processing Record 49 of Set 13 | champerico
# Processing Record 50 of Set 13 | ahuimanu
# Processing Record 1 of Set 14 | cochrane
# Processing Record 2 of Set 14 | villazon
# Processing Record 3 of Set 14 | liuzhou
# Processing Record 4 of Set 14 | saint-joseph
# Processing Record 5 of Set 14 | christchurch
# Processing Record 6 of Set 14 | praia
# Processing Record 7 of Set 14 | kalmunai
# Processing Record 8 of Set 14 | shenyang
# Processing Record 9 of Set 14 | tabuk
# Processing Record 10 of Set 14 | salalah
# Processing Record 11 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 12 of Set 14 | merauke
# Processing Record 13 of Set 14 | carutapera
# Processing Record 14 of Set 14 | shahrud
# Processing Record 15 of Set 14 | talcahuano
# Processing Record 16 of Set 14 | lasa
# Processing Record 17 of Set 14 | flin flon
# Processing Record 18 of Set 14 | mehamn
# Processing Record 19 of Set 14 | adrar
# Processing Record 20 of Set 14 | balkhash
# Processing Record 21 of Set 14 | cairns
# Processing Record 22 of Set 14 | madison
# Processing Record 23 of Set 14 | saint-pierre
# Processing Record 24 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 25 of Set 14 | port said
# Processing Record 26 of Set 14 | rjukan
# Processing Record 27 of Set 14 | tilichiki
# Processing Record 28 of Set 14 | choma
# Processing Record 29 of Set 14 | okha
# Processing Record 30 of Set 14 | ternate
# Processing Record 31 of Set 14 | houma
# Processing Record 32 of Set 14 | opuwo
# Processing Record 33 of Set 14 | datong
# Processing Record 34 of Set 14 | beaverlodge
# Processing Record 35 of Set 14 | canutama
# Processing Record 36 of Set 14 | manta
# Processing Record 37 of Set 14 | kerteh
# City not found. Skipping...
# Processing Record 38 of Set 14 | zalesovo
# Processing Record 39 of Set 14 | aklavik
# Processing Record 40 of Set 14 | zdice
# Processing Record 41 of Set 14 | george
# Processing Record 42 of Set 14 | taoudenni
# Processing Record 43 of Set 14 | bilibino
# Processing Record 44 of Set 14 | dicabisagan
# Processing Record 45 of Set 14 | urumqi
# Processing Record 46 of Set 14 | cabedelo
# Processing Record 47 of Set 14 | eyemouth
# Processing Record 48 of Set 14 | sukabumi
# Processing Record 49 of Set 14 | burica
# City not found. Skipping...
# Processing Record 50 of Set 14 | tucumcari
# Processing Record 1 of Set 15 | lampa
# Processing Record 2 of Set 15 | pendleton
# Processing Record 3 of Set 15 | tessalit
# Processing Record 4 of Set 15 | kalulushi
# Processing Record 5 of Set 15 | pafos
# Processing Record 6 of Set 15 | camacha
# Processing Record 7 of Set 15 | vikhorevka
# Processing Record 8 of Set 15 | ous
# Processing Record 9 of Set 15 | caucaia
# Processing Record 10 of Set 15 | west bay
# Processing Record 11 of Set 15 | hongjiang
# Processing Record 12 of Set 15 | iralaya
# Processing Record 13 of Set 15 | mahudha
# Processing Record 14 of Set 15 | shitkino
# Processing Record 15 of Set 15 | bassano
# Processing Record 16 of Set 15 | tornio
# Processing Record 17 of Set 15 | kang
# Processing Record 18 of Set 15 | wanxian
# Processing Record 19 of Set 15 | watsonville
# Processing Record 20 of Set 15 | mbanza-ngungu
# Processing Record 21 of Set 15 | trinidad
# Processing Record 22 of Set 15 | artyk
# City not found. Skipping...
# Processing Record 23 of Set 15 | maine-soroa
# Processing Record 24 of Set 15 | alice springs
# Processing Record 25 of Set 15 | jiquilisco
# Processing Record 26 of Set 15 | jadu
# Processing Record 27 of Set 15 | haileybury
# Processing Record 28 of Set 15 | minbu
# Processing Record 29 of Set 15 | kondinskoye
# Processing Record 30 of Set 15 | valley city
# Processing Record 31 of Set 15 | pemex
# Processing Record 32 of Set 15 | giyani
# Processing Record 33 of Set 15 | santa ana
# Processing Record 34 of Set 15 | chicama
# Processing Record 35 of Set 15 | henties bay
# Processing Record 36 of Set 15 | denpasar
# Processing Record 37 of Set 15 | homer
# Processing Record 38 of Set 15 | novobirilyussy
# Processing Record 39 of Set 15 | marystown
# Processing Record 40 of Set 15 | pfarrkirchen
# Processing Record 41 of Set 15 | big rapids
# Processing Record 42 of Set 15 | hervey bay
# Processing Record 43 of Set 15 | hudson bay
# Processing Record 44 of Set 15 | tanshui
# City not found. Skipping...
# Processing Record 45 of Set 15 | maxixe
# Processing Record 46 of Set 15 | karaton
# Processing Record 47 of Set 15 | umkomaas
# Processing Record 48 of Set 15 | mvomero
# Processing Record 49 of Set 15 | ozorkow
# Processing Record 50 of Set 15 | cherskiy
# Processing Record 1 of Set 16 | porto novo
# Processing Record 2 of Set 16 | kaihua
# Processing Record 3 of Set 16 | shakawe
# Processing Record 4 of Set 16 | cabo rojo
# Processing Record 5 of Set 16 | majene
# Processing Record 6 of Set 16 | le havre
# Processing Record 7 of Set 16 | estevan
# Processing Record 8 of Set 16 | keskin
# Processing Record 9 of Set 16 | awbari
# Processing Record 10 of Set 16 | cukai
# Processing Record 11 of Set 16 | mahajanga
# Processing Record 12 of Set 16 | chunhuhub
# Processing Record 13 of Set 16 | daokou
# Processing Record 14 of Set 16 | samarai
# Processing Record 15 of Set 16 | port-de-paix
# City not found. Skipping...
# Processing Record 16 of Set 16 | gaomi
# Processing Record 17 of Set 16 | balaipungut
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Baykit      RU  61.6700   96.3700     70.02        54          59
# 1        Castro      BR -24.7911  -50.0119     56.25        96         100
# 2  Puerto Ayora      EC  -0.7393  -90.3518     67.55        96          41
# 3       Omaruru      NA -21.4333   15.9333     55.92        44          38
# 4          Bure      ET  10.7000   37.0667     56.71        99         100
# 5        Sinnai      IT  39.3042    9.2036     76.48        79           0
# 6       Mataura      NZ -46.1927  168.8643     42.48        69           7
# 7        Torbay      CA  47.6666  -52.7314     69.58        91         100
# 8   La Macarena      CO   2.1837  -73.7849     71.60        97           9
# 9    Maksatikha      RU  57.7970   35.8825     53.08        87          37
#
#    Wind Speed   Current Description
# 0        3.22            light rain
# 1        6.78         moderate rain
# 2        7.00      scattered clouds
# 3        4.72      scattered clouds
# 4        1.99  heavy intensity rain
# 5        5.75             clear sky
# 6        9.44             clear sky
# 7       21.85       overcast clouds
# 8        2.13             clear sky
# 9        2.04      scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="Weather_ID")
